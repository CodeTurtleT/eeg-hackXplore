# %%
from pathlib import Path
import mne

file_path = Path("/Users/trinity/Documents/GitHub/eeg-hackXplore") / \
            "measurement data-the amplitude" / \
            "med2_27_06_2026_10_30_13.bdf"

raw = mne.io.read_raw_bdf(file_path, preload=True)

raw.save('dein_file_raw.fif', overwrite=True)

raw.save("/Users/trinity/Documents/GitHub/eeg-hackXplore/fif-files/med2_27_06_2026_10_30_13_raw.fif",
         overwrite=True)
# Out:
# Extracting EDF parameters from /Users/trinity/Documents/GitHub/eeg-hackXplore/measurement data-the amplitude/med2_27_06_2026_10_30_13.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 12275  =      0.000 ...    49.100 secs...
# Writing /Users/trinity/Documents/GitHub/eeg-hackXplore/dein_file_raw.fif
# Closing /Users/trinity/Documents/GitHub/eeg-hackXplore/dein_file_raw.fif
# [done]
# [PosixPath('/Users/trinity/Documents/GitHub/eeg-hackXplore/dein_file_raw.fif')]
